# %% [markdown]
# ## Reading External Data and Plotting

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# when you want read a csv file, we use the pd.read_csv() method
# for example, let's read the folder "data"
df = pd.read_csv('data/btc-market-price.csv')

# %%
# we use the .head() method to display the first  rows of the dataframe
df.head()
# Out:
#    2017-04-02 00:00:00  1099.169125
# 0  2017-04-03 00:00:00  1141.813000
# 1  2017-04-04 00:00:00  1141.600363
# 2  2017-04-05 00:00:00  1133.079314
# 3  2017-04-06 00:00:00  1196.307937
# 4  2017-04-07 00:00:00  1190.454250

# %%
# let's create new columns in the csv 'data' by using the .columns method
df.columns = ['Timestamp', 'Price']

# %%
# we use the .head() method to display the first  rows of the dataframe
# the first 5 rows of the dataframe
df.head()
# Out:
#              Timestamp        Price
# 0  2017-04-03 00:00:00  1141.813000
# 1  2017-04-04 00:00:00  1141.600363
# 2  2017-04-05 00:00:00  1133.079314
# 3  2017-04-06 00:00:00  1196.307937
# 4  2017-04-07 00:00:00  1190.454250

# %%
df.shape
# Out:
# (364, 2)

# %%
# we use the .tail() method to display the last  rows of the dataframe
# the last 5 rows of the dataframe
df.tail()
# Out:
#                Timestamp        Price
# 359  2018-03-28 00:00:00  7960.380000
# 360  2018-03-29 00:00:00  7172.280000
# 361  2018-03-30 00:00:00  6882.531667
# 362  2018-03-31 00:00:00  6935.480000
# 363  2018-04-01 00:00:00  6794.105000

# %%
df.dtypes
# Out:
# Timestamp     object
# Price        float64
# dtype: object

# %%
pd.to_datetime(df['Timestamp']).head()
# Out:
# 0   2017-04-03
# 1   2017-04-04
# 2   2017-04-05
# 3   2017-04-06
# 4   2017-04-07
# Name: Timestamp, dtype: datetime64[ns]

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df.head()
# Out:
#    Timestamp        Price
# 0 2017-04-03  1141.813000
# 1 2017-04-04  1141.600363
# 2 2017-04-05  1133.079314
# 3 2017-04-06  1196.307937
# 4 2017-04-07  1190.454250

# %%
df.dtypes
# Out:
# Timestamp    datetime64[ns]
# Price               float64
# dtype: object

# %%
df.head()
# Out:
#                   Price
# Timestamp
# 2017-04-03  1141.813000
# 2017-04-04  1141.600363
# 2017-04-05  1133.079314
# 2017-04-06  1196.307937
# 2017-04-07  1190.454250

# %%
# let's check the price of bitcoin in 2017/09/29
df.loc['2017-09-29']
# Out:
# Price    4193.574667
# Name: 2017-09-29 00:00:00, dtype: float64

# %% [markdown]
# ## Summary Of What We Did So Far

# %%
df = pd.read_csv('data/btc-market-price.csv')
df.columns = ['Timestamp', 'Price'] 
pd.to_datetime(df['Timestamp']).head()
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %% [markdown]
# #### this should be much simpler and faster

# %%
pd.read_csv(
    'data/btc-market-price.csv',
    names=['Timestamp', 'Price'],
    header=0,
    index_col=0,
    parse_dates=True

)
# Out:
#                   Price
# Timestamp
# 2017-04-03  1141.813000
# 2017-04-04  1141.600363
# 2017-04-05  1133.079314
# 2017-04-06  1196.307937
# 2017-04-07  1190.454250
# ...                 ...
# 2018-03-28  7960.380000
# 2018-03-29  7172.280000
# 2018-03-30  6882.531667
# 2018-03-31  6935.480000
# 2018-04-01  6794.105000
#
# [364 rows x 1 columns]
