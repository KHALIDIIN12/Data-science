# %%
# this is how to import pandas library
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## Pandas series

# %%
g7_pop = pd.Series([67.2, 65.3, 126.7, 60.7, 46.4, 64.6, 66.0])
g7_pop
# Out:
# 0     67.2
# 1     65.3
# 2    126.7
# 3     60.7
# 4     46.4
# 5     64.6
# 6     66.0
# dtype: float64

# %%
#series can also have a name which is useful for labeling data.
g7_pop.name = 'G7 Population in millions'
g7_pop
# Out:
# 0     67.2
# 1     65.3
# 2    126.7
# 3     60.7
# 4     46.4
# 5     64.6
# 6     66.0
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop.dtype
# Out:
# dtype('float64')

# %%
#you can also check values of the series using the values attribute.
g7_pop.values
# Out:
# array([ 67.2,  65.3, 126.7,  60.7,  46.4,  64.6,  66. ])

# %%
g7_pop
# Out:
# 0     67.2
# 1     65.3
# 2    126.7
# 3     60.7
# 4     46.4
# 5     64.6
# 6     66.0
# Name: G7 Population in millions, dtype: float64

# %%
# you can also get elements of the series using the index attribute.
g7_pop[2]
# Out:
# np.float64(126.7)

# %%
g7_pop[0:4]
# Out:
# 0     67.2
# 1     65.3
# 2    126.7
# 3     60.7
# Name: G7 Population in millions, dtype: float64

# %%
# you can also set the index of the series using the index attribute.
g7_pop.index = [
    'canada',
    'france',
    'germany',
    'italy',
    'japan',
    'united kingdom',
    'united states'
]
g7_pop
# Out:
# canada             67.2
# france             65.3
# germany           126.7
# italy              60.7
# japan              46.4
# united kingdom     64.6
# united states      66.0
# Name: G7 Population in millions, dtype: float64

# %%
# you can also bypass the creation of the series and create it directly with ordered dictionary.
g7_pop = pd.Series({
    'canada' : 67.2,
    'france' : 65.3,
    'germany' : 126.7,
    'italy' : 60.7,
    'japan' : 46.4,
    'united kingdom' : 64.6,
    'united states' : 66.0
}, name = 'G7 Population in millions')
g7_pop
# Out:
# canada             67.2
# france             65.3
# germany           126.7
# italy              60.7
# japan              46.4
# united kingdom     64.6
# united states      66.0
# Name: G7 Population in millions, dtype: float64

# %% [markdown]
# ## Indexing

# %%
# you can use the 'index' of the element you are looking for
g7_pop['germany']
# Out:
# np.float64(126.7)

# %%
g7_pop
# Out:
# canada             67.2
# france             65.3
# germany           126.7
# italy              60.7
# japan              46.4
# united kingdom     64.6
# united states      66.0
# Name: G7 Population in millions, dtype: float64

# %%
# you can also get two elements of the series
g7_pop[['japan' , 'germany']]
# Out:
# japan       46.4
# germany    126.7
# Name: G7 Population in millions, dtype: float64

# %% [markdown]
# ## Conditional Selection (boolean arrays)

# %%
g7_pop
# Out:
# canada             67.2
# france             65.3
# germany           126.7
# italy              60.7
# japan              46.4
# united kingdom     64.6
# united states      66.0
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop >= 73
# Out:
# canada            False
# france            False
# germany            True
# italy             False
# japan             False
# united kingdom    False
# united states     False
# Name: G7 Population in millions, dtype: bool

# %% [markdown]
# ## Operation and Methods

# %%
g7_pop
# Out:
# canada             67.2
# france             65.3
# germany           126.7
# italy              60.7
# japan              46.4
# united kingdom     64.6
# united states      66.0
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop = g7_pop * -1_000_000
g7_pop
# Out:
# canada            -67200000.0
# france            -65300000.0
# germany          -126700000.0
# italy             -60700000.0
# japan             -46400000.0
# united kingdom    -64600000.0
# united states     -66000000.0
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop.mean()
# Out:
# np.float64(-70985714.28571428)

# %%
g7_pop
# Out:
# canada            -67200000.0
# france            -65300000.0
# germany          -126700000.0
# italy             -60700000.0
# japan             -46400000.0
# united kingdom    -64600000.0
# united states     -66000000.0
# Name: G7 Population in millions, dtype: float64

# %% [markdown]
# ## Pandas DataFrame

# %%
# when creating a dataframe, you can pass a dictionary of series to the constructor. 
# The keys of the dictionary will be used as the column names 
# and the values will be used as the data for each column.
df = pd.DataFrame({
    'population': [67.2, 65.3, 126.7, 60.7, 46.4, 64.6, 66.0],
    'surface area': [9.985, 0.551, 0.357, 0.301, 0.378, 0.243, 9.834],
    'continent': [
        'South america', 
        'Asia',  
        'Europe', 
        'Europe',
        'Europe',
        'Europe',
        'North america'
    ]
})
df
# Out:
#    population  surface area      continent
# 0        67.2         9.985  South america
# 1        65.3         0.551           Asia
# 2       126.7         0.357         Europe
# 3        60.7         0.301         Europe
# 4        46.4         0.378         Europe
# 5        64.6         0.243         Europe
# 6        66.0         9.834  North america

# %%
#lets assign the index of the dataframe to be the country names.
df.index = [
    'canada',
    'france',
    'germany',
    'italy',
    'japan',
    'united kingdom',
    'united states'
] 
df
# Out:
#                 population  surface area      continent
# canada                67.2         9.985  South america
# france                65.3         0.551           Asia
# germany              126.7         0.357         Europe
# italy                 60.7         0.301         Europe
# japan                 46.4         0.378         Europe
# united kingdom        64.6         0.243         Europe
# united states         66.0         9.834  North america

# %%
## when getting the columns of a dataframe, 
# you can use the column name as an attribute of the dataframe.
df.columns
# Out:
# Index(['population', 'surface area', 'continent'], dtype='object')

# %%
# when getting the index of a dataframe, you can use the index attribute of the dataframe.
df.index
# Out:
# Index(['canada', 'france', 'germany', 'italy', 'japan', 'united kingdom',
#        'united states'],
#       dtype='object')

# %%
# when you want to get quick info about the dataframe, you can use the info() method of the dataframe.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, canada to united states
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   population    7 non-null      float64
#  1   surface area  7 non-null      float64
#  2   continent     7 non-null      object
# dtypes: float64(2), object(1)
# memory usage: 224.0+ bytes

# %%
# when getting size of the dataframe, you can use the shape attribute of the dataframe.
df.size
# Out:
# 21

# %%
# when getting the shape of the dataframe, you can use the shape attribute of the dataframe.
df.shape
# Out:
# (7, 3)

# %%
# if you want to get the summary of the dataframe, you can use the describe() method of the dataframe.
df.describe()
# Out:
#        population  surface area
# count    7.000000      7.000000
# mean    70.985714      3.092714
# std     25.581988      4.657918
# min     46.400000      0.243000
# 25%     62.650000      0.329000
# 50%     65.300000      0.378000
# 75%     66.600000      5.192500
# max    126.700000      9.985000

# %%
# when getting the types of the columns in the dataframe, you can use the dtypes attribute of the dataframe.
df.dtypes
# Out:
# population      float64
# surface area    float64
# continent        object
# dtype: object

# %% [markdown]
# ## Indexing, Selection and Slicing

# %%
df
# Out:
#                 population  surface area      continent
# canada                67.2         9.985  South america
# france                65.3         0.551           Asia
# germany              126.7         0.357         Europe
# italy                 60.7         0.301         Europe
# japan                 46.4         0.378         Europe
# united kingdom        64.6         0.243         Europe
# united states         66.0         9.834  North america

# %%
# when selecting individual rows of the dataframe, you can use the loc[] method of the dataframe.
df.loc['italy']
# Out:
# population        60.7
# surface area     0.301
# continent       Europe
# Name: italy, dtype: object

# %%
# we use iloc[] method to select rows by their integer index.
df.iloc[-1]
# Out:
# population               66.0
# surface area            9.834
# continent       North america
# Name: united states, dtype: object

# %%
df.iloc[3]
# Out:
# population        60.7
# surface area     0.301
# continent       Europe
# Name: italy, dtype: object

# %%
df
# Out:
#                 population  surface area      continent
# canada                67.2         9.985  South america
# france                65.3         0.551           Asia
# germany              126.7         0.357         Europe
# italy                 60.7         0.301         Europe
# japan                 46.4         0.378         Europe
# united kingdom        64.6         0.243         Europe
# united states         66.0         9.834  North america

# %%
# when you want to select a column of the dataframe, you use the dataframe name 
# followed by the column name in square brackets.
df['continent']
# Out:
# canada            South america
# france                     Asia
# germany                  Europe
# italy                    Europe
# japan                    Europe
# united kingdom           Europe
# united states     North america
# Name: continent, dtype: object

# %%
# you can also get a row (-up to) and a column by using the loc[] method of the dataframe.
df.loc['france' : 'united kingdom', 'population']
# Out:
# france             65.3
# germany           126.7
# italy              60.7
# japan              46.4
# united kingdom     64.6
# Name: population, dtype: float64

# %%
#same using iloc[] method to get the same result as above.
df.iloc[1 : 5, 0]
# Out:
# france      65.3
# germany    126.7
# italy       60.7
# japan       46.4
# Name: population, dtype: float64

# %%
# the same as above but if you want to get two coloumns, you can pass a list of 
# column names to the loc[] method.
df.loc['france' : 'united kingdom', ['population', 'surface area']]
# Out:
#                 population  surface area
# france                65.3         0.551
# germany              126.7         0.357
# italy                 60.7         0.301
# japan                 46.4         0.378
# united kingdom        64.6         0.243

# %%
# this time using iloc[] method to get the same result as above.
df.iloc[1 : 5, [0, 1]]
# Out:
#          population  surface area
# france         65.3         0.551
# germany       126.7         0.357
# italy          60.7         0.301
# japan          46.4         0.378

# %% [markdown]
# ## Conditional Selection

# %%
df
# Out:
#                 population  surface area      continent
# canada                67.2         9.985  South america
# france                65.3         0.551           Asia
# germany              126.7         0.357         Europe
# italy                 60.7         0.301         Europe
# japan                 46.4         0.378         Europe
# united kingdom        64.6         0.243         Europe
# united states         66.0         9.834  North america

# %%
df['population'] >= 55.8
# Out:
# canada             True
# france             True
# germany            True
# italy              True
# japan             False
# united kingdom     True
# united states      True
# Name: population, dtype: bool

# %%
# use .loc method when you want to get the rows of the dataframe that satisfy a certain condition.
df.loc[df['population'] >= 55.8]
# Out:
#                 population  surface area      continent
# canada                67.2         9.985  South america
# france                65.3         0.551           Asia
# germany              126.7         0.357         Europe
# italy                 60.7         0.301         Europe
# united kingdom        64.6         0.243         Europe
# united states         66.0         9.834  North america

# %% [markdown]
# ## Dropping stuff

# %%
df
# Out:
#                 population  surface area      continent
# canada                67.2         9.985  South america
# france                65.3         0.551           Asia
# germany              126.7         0.357         Europe
# italy                 60.7         0.301         Europe
# japan                 46.4         0.378         Europe
# united kingdom        64.6         0.243         Europe
# united states         66.0         9.834  North america

# %%
# you use the .drop() method if you want to drop a column or a row from the dataframe.
df.drop('canada')
# Out:
#                 population  surface area      continent
# france                65.3         0.551           Asia
# germany              126.7         0.357         Europe
# italy                 60.7         0.301         Europe
# japan                 46.4         0.378         Europe
# united kingdom        64.6         0.243         Europe
# united states         66.0         9.834  North america

# %%
df.drop(columns = ['continent'])
# Out:
#                 population  surface area
# canada                67.2         9.985
# france                65.3         0.551
# germany              126.7         0.357
# italy                 60.7         0.301
# japan                 46.4         0.378
# united kingdom        64.6         0.243
# united states         66.0         9.834

# %% [markdown]
# ## Modyfing DataFrames

# %%
## earlier when we used the drop() method, we did not actually modify the dataframe
df
# Out:
#                 population  surface area      continent
# canada                67.2         9.985  South america
# france                65.3         0.551           Asia
# germany              126.7         0.357         Europe
# italy                 60.7         0.301         Europe
# japan                 46.4         0.378         Europe
# united kingdom        64.6         0.243         Europe
# united states         66.0         9.834  North america

# %%
df.drop('canada')
# Out:
#                 population  surface area      continent
# france                65.3         0.551           Asia
# germany              126.7         0.357         Europe
# italy                 60.7         0.301         Europe
# japan                 46.4         0.378         Europe
# united kingdom        64.6         0.243         Europe
# united states         66.0         9.834  North america

# %%
# when i call df you will see that the canada row is still there.
# this is because the drop() method returns a new dataframe with the specified row or column dropped, 
# but it does not modify the original dataframe unless you specify the inplace=True parameter.
df
# Out:
#                 population  surface area      continent
# canada                67.2         9.985  South america
# france                65.3         0.551           Asia
# germany              126.7         0.357         Europe
# italy                 60.7         0.301         Europe
# japan                 46.4         0.378         Europe
# united kingdom        64.6         0.243         Europe
# united states         66.0         9.834  North america

# %%
df
# Out:
#                 population  surface area      continent
# canada                67.2         9.985  South america
# france                65.3         0.551           Asia
# germany              126.7         0.357         Europe
# italy                 60.7         0.301         Europe
# japan                 46.4         0.378         Europe
# united kingdom        64.6         0.243         Europe
# united states         66.0         9.834  North america

# %%
# when adding a new column to the dataframe
Language = pd.Series(
    ['English', 'French', 'German', 'Italian', 'Japanese', 'English', 'English'],
    index = ['canada', 'france', 'germany', 'italy', 'japan', 'united kingdom', 'united states']

)
df['language'] = Language
df
# Out:
#                 population  surface area      continent  language
# canada                67.2         9.985  South america   English
# france                65.3         0.551           Asia    French
# germany              126.7         0.357         Europe    German
# italy                 60.7         0.301         Europe   Italian
# japan                 46.4         0.378         Europe  Japanese
# united kingdom        64.6         0.243         Europe   English
# united states         66.0         9.834  North america   English

# %% [markdown]
# ## Replacing Values Per Column

# %%
df['language'] = 'Japanease'
df
# Out:
#                 population  surface area      continent   language
# canada                67.2         9.985  South america  Japanease
# france                65.3         0.551           Asia  Japanease
# germany              126.7         0.357         Europe  Japanease
# italy                 60.7         0.301         Europe  Japanease
# japan                 46.4         0.378         Europe  Japanease
# united kingdom        64.6         0.243         Europe  Japanease
# united states         66.0         9.834  North america  Japanease

# %% [markdown]
# ## Renaming Columns

# %%
# when renaming columns of the datafram, we use the .rename() method
df.rename(
    columns = {
        'surface area' : ' S.Area',
        'language' : 'Language'
    }
)
# Out:
#                 population   S.Area      continent   Language
# canada                67.2    9.985  South america  Japanease
# france                65.3    0.551           Asia  Japanease
# germany              126.7    0.357         Europe  Japanease
# italy                 60.7    0.301         Europe  Japanease
# japan                 46.4    0.378         Europe  Japanease
# united kingdom        64.6    0.243         Europe  Japanease
# united states         66.0    9.834  North america  Japanease

# %%
# same thing as above but renaming the index of the dataframe instead of the columns.
df.rename(
    index = {
        'canada' : 'Canada',
        'france' : 'France',
        'germany' : 'Germany',
        'italy' : 'Italy',
        'japan' : 'Japan',
        'united kingdom' : 'United Kingdom',
        'united states' : 'United States'
    }
)
# Out:
#                 population  surface area      continent   language
# Canada                67.2         9.985  South america  Japanease
# France                65.3         0.551           Asia  Japanease
# Germany              126.7         0.357         Europe  Japanease
# Italy                 60.7         0.301         Europe  Japanease
# Japan                 46.4         0.378         Europe  Japanease
# United Kingdom        64.6         0.243         Europe  Japanease
# United States         66.0         9.834  North america  Japanease

# %% [markdown]
# ## Creating columns from other Columns

# %%
# when creating a new column from other columns of the dataframe,
#we use arithmetic operations on the columns of the dataframe.

# %%
df
# Out:
#                 population  surface area      continent   language
# canada                67.2         9.985  South america  Japanease
# france                65.3         0.551           Asia  Japanease
# germany              126.7         0.357         Europe  Japanease
# italy                 60.7         0.301         Europe  Japanease
# japan                 46.4         0.378         Europe  Japanease
# united kingdom        64.6         0.243         Europe  Japanease
# united states         66.0         9.834  North america  Japanease

# %%
df['population'] / df['surface area']
# Out:
# canada              6.730095
# france            118.511797
# germany           354.901961
# italy             201.661130
# japan             122.751323
# united kingdom    265.843621
# united states       6.711409
# dtype: float64

# %%
df['High'] = df['population'] / df['surface area']
df
# Out:
#                 population  surface area      continent   language        High
# canada                67.2         9.985  South america  Japanease    6.730095
# france                65.3         0.551           Asia  Japanease  118.511797
# germany              126.7         0.357         Europe  Japanease  354.901961
# italy                 60.7         0.301         Europe  Japanease  201.661130
# japan                 46.4         0.378         Europe  Japanease  122.751323
# united kingdom        64.6         0.243         Europe  Japanease  265.843621
# united states         66.0         9.834  North america  Japanease    6.711409
