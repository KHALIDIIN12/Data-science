# %%
# this is how to import pandas library
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## Pandas series

# %%
g7_pop = pd.Series([67.2, 65.3, 126.7, 60.7, 46.4, 64.6, 66.0])
g7_pop
# Out:
# 0     67.2
# 1     65.3
# 2    126.7
# 3     60.7
# 4     46.4
# 5     64.6
# 6     66.0
# dtype: float64

# %%
#series can also have a name which is useful for labeling data.
g7_pop.name = 'G7 Population in millions'
g7_pop
# Out:
# 0     67.2
# 1     65.3
# 2    126.7
# 3     60.7
# 4     46.4
# 5     64.6
# 6     66.0
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop.dtype
# Out:
# dtype('float64')

# %%
#you can also check values of the series using the values attribute.
g7_pop.values
# Out:
# array([ 67.2,  65.3, 126.7,  60.7,  46.4,  64.6,  66. ])

# %%
g7_pop
# Out:
# 0     67.2
# 1     65.3
# 2    126.7
# 3     60.7
# 4     46.4
# 5     64.6
# 6     66.0
# Name: G7 Population in millions, dtype: float64

# %%
# you can also get elements of the series using the index attribute.
g7_pop[2]
# Out:
# np.float64(126.7)

# %%
g7_pop[0:4]
# Out:
# 0     67.2
# 1     65.3
# 2    126.7
# 3     60.7
# Name: G7 Population in millions, dtype: float64

# %%
# you can also set the index of the series using the index attribute.
g7_pop.index = [
    'canada',
    'france',
    'germany',
    'italy',
    'japan',
    'united kingdom',
    'united states'
]
g7_pop
# Out:
# canada             67.2
# france             65.3
# germany           126.7
# italy              60.7
# japan              46.4
# united kingdom     64.6
# united states      66.0
# Name: G7 Population in millions, dtype: float64

# %%
# you can also bypass the creation of the series and create it directly with ordered dictionary.
g7_pop = pd.Series({
    'canada' : 67.2,
    'france' : 65.3,
    'germany' : 126.7,
    'italy' : 60.7,
    'japan' : 46.4,
    'united kingdom' : 64.6,
    'united states' : 66.0
}, name = 'G7 Population in millions')
g7_pop
# Out:
# canada             67.2
# france             65.3
# germany           126.7
# italy              60.7
# japan              46.4
# united kingdom     64.6
# united states      66.0
# Name: G7 Population in millions, dtype: float64

# %% [markdown]
# ## Indexing

# %%
# you can use the 'index' of the element you are looking for
g7_pop['germany']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 2
#       1 # you can use the 'index' of the element you are looking for
# ----> 2 g7_pop['china', 'Germany']
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1165, in Series.__getitem__(self, key)
#    1162     key = np.asarray(key, dtype=bool)
#    1163     return self._get_rows_with_mask(key)
# -> 1165 return self._get_with(key)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1175, in Series._get_with(self, key)
#    1170     raise TypeError(
#    1171         "Indexing a Series with DataFrame is not "
#    1172         "supported, use the appropriate DataFrame column"
#    1173     )
#    1174 elif isinstance(key, tuple):
# -> 1175     return self._get_values_tuple(key)
#    1177 elif not is_list_like(key):
#    1178     # e.g. scalars that aren't recognized by lib.is_scalar, GH#32684
#    1179     return self.loc[key]
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1219, in Series._get_values_tuple(self, key)
#    1216     return result
#    1218 if not isinstance(self.index, MultiIndex):
# -> 1219     raise KeyError("key of type tuple not found and not a MultiIndex")
#    1221 # If key is contained, would have returned by now
#    1222 indexer, new_index = self.index.get_loc_level(key)
#
# KeyError: 'key of type tuple not found and not a MultiIndex'
