# %%
import numpy as np
import pandas as pd

# %%
pd.isnull((np.nan))
# Out:
# True

# %% [markdown]
# ## Pandas Operations With Missing Values

# %%
s = pd.Series([1, 2, np.nan])

# %% [markdown]
# ## Dropping Values

# %%
s.dropna()
# Out:
# 0    1.0
# 1    2.0
# dtype: float64

# %% [markdown]
# ## Filling nulls with a arbitrary values

# %%
s.fillna(0)
# Out:
# 0    1.0
# 1    2.0
# 2    0.0
# dtype: float64

# %% [markdown]
# ## filling nulls with close values

# %%
# the method argument is used to fill null values with other values close to that null one
s.fillna(method = 'ffill')
# Out:
# /var/folders/zn/q9_l5xb11sd2s50rhjfnnmsm0000gn/T/ipykernel_79962/1151866447.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   s.fillna(method = 'ffill')
# 0    1.0
# 1    2.0
# 2    2.0
# dtype: float64

# %%
#now backwards fill
s.fillna(method = 'bfill')
# Out:
# /var/folders/zn/q9_l5xb11sd2s50rhjfnnmsm0000gn/T/ipykernel_79962/913945391.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   s.fillna(method = 'bfill')
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %% [markdown]
# ## checking if there are NAs

# %%
#if there are missing values, s.dropna() will have less elements than s.
s.dropna().count()
# Out:
# np.int64(2)
