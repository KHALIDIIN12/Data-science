# %%
import numpy as np
import pandas as pd

# %%
pd.isnull((np.nan))
# Out:
# True

# %% [markdown]
# ## Pandas Operations With Missing Values

# %%
s = pd.Series([1, 2, np.nan])

# %% [markdown]
# ## Dropping Values

# %%
s.dropna()
# Out:
# 0    1.0
# 1    2.0
# dtype: float64
