# %%
print('hello world!')
# Out:
# hello world!

# %%
# notebooks(ipynb) are organized into cells

# %%
animals = [' hyena', 'antelope', 'lion', 'jaguar']
print(animals)
# Out:
# [' hyena', 'antelope', 'lion', 'jaguar']

# %%
animals = [' hyena', 'antelope', 'lion', 'jaguar']
animals[1] = 'bufalo'
print(animals)
# Out:
# [' hyena', 'bufalo', 'lion', 'jaguar']

# %%
animal = ['antelope', 'bear', 'cat']
def which_animall(animal):
    if animal == 'antelope' and animal == 'bear':
        print("is a wild animal")
    else:
        print("is a domestic animal")

# %%
n =3

# %%
2 ** n
# Out:
# 8
